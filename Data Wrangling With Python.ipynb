# %% [markdown]
# # DATA WRANGLING WITH PYTHON

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('test.csv', sep =';')

# %%
df
# Out:
#     IMBD title ID               Original titlÊ  Release year  \
# 0       tt0111161     The Shawshank Redemption    1995-02-10
# 1       tt0068646                The Godfather    09 21 1972
# 2       tt0468569              The Dark Knight   23 -07-2008
# 3       tt0071562       The Godfather: Part II    1975-09-25
# 4       tt0110912                 Pulp Fiction    1994-10-28
# ..            ...                          ...           ...
# 96      tt0070735                    The Sting    1974-03-21
# 97      tt0082096                     Das Boot    1982-03-18
# 98      tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99      tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100     tt0045152          Singin' in the Rain    1953-02-05
#
#                          Genrë¨ Duration       Country Content Rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %%
df.shape
# Out:
# (101, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   IMBD title ID   100 non-null    object
#  1   Original titlÊ  100 non-null    object
#  2   Release year    100 non-null    object
#  3   Genrë¨          100 non-null    object
#  4   Duration        99 non-null     object
#  5   Country         100 non-null    object
#  6   Content Rating  77 non-null     object
#  7   Director        100 non-null    object
#  8   Unnamed: 8      0 non-null      float64
#  9   Income          100 non-null    object
#  10   Votes          100 non-null    object
#  11  Score           100 non-null    object
# dtypes: float64(1), object(11)
# memory usage: 9.6+ KB

# %%
# Rename columns

# %%
df.columns = df.columns.str.lower()

# %%
df.columns = df.columns.str.replace(' ','_')

# %%
df.head()
# Out:
#   imbd_title_id            original_title  release_year                 genre  \
# 0     tt0111161  The Shawshank Redemption    1995-02-10                 Drama
# 1     tt0068646             The Godfather    09 21 1972          Crime, Drama
# 2     tt0468569           The Dark Knight   23 -07-2008  Action, Crime, Drama
# 3     tt0071562    The Godfather: Part II    1975-09-25          Crime, Drama
# 4     tt0110912              Pulp Fiction    1994-10-28          Crime, Drama
#
#   duration country content_rating              director  unnamed:_8  \
# 0      142     USA              R        Frank Darabont         NaN
# 1      175     USA              R  Francis Ford Coppola         NaN
# 2      152      US          PG-13     Christopher Nolan         NaN
# 3      220     USA              R  Francis Ford Coppola         NaN
# 4              USA              R     Quentin Tarantino         NaN
#
#           income      votes score
# 0     $ 28815245  2.278.845   9.3
# ...

# %%
df = df.rename(columns ={'genrë¨':'genre','original_titlê':'original_title','_votes_':'votes' })

# %%
# Delete Columns

# %%
df=df.drop(['unnamed:_8'], axis=1)

# %%
df=df.drop(['imbd_title_id'], axis=1)

# %% [markdown]
# #### Checking for null values

# %%
df[df.isnull().any(axis =1)]
# Out:
#                         original_title                 release_year  \
# 13                                 NaN                          NaN
# 14                          The Matrix                   1999-05-07
# 27                    La vita B9 bella                   1997-12-20
# 28                        Gisaengchung                   2019-11-07
# 36                               LÃ©on                   1995-04-07
# 40                               Joker                   2019-10-03
# 41                        Intouchables                   2012-02-24
# 47                      Hotaru no haka                   2015-10-11
# 48               Nuovo Cinema Paradiso                   1988-11-17
# 56              Avengers: Infinity War                   2018-04-25
# 58                   Avengers: Endgame                   2019-04-24
# 62                         Rear Window                   1955-04-14
# 63                                Coco                   2017-12-28
# ...

# %%
# Delete row
df.drop(labels=13, axis =0, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   original_title  100 non-null    object
#  1   release_year    100 non-null    object
#  2   genre           100 non-null    object
#  3   duration        99 non-null     object
#  4   country         100 non-null    object
#  5   content_rating  77 non-null     object
#  6   director        100 non-null    object
#  7   income          100 non-null    object
#  8   votes           100 non-null    object
#  9   score           100 non-null    object
# dtypes: object(10)
# memory usage: 8.6+ KB

# %% [markdown]
# ### Replace Values In Pandas

# %%
df['score']=df['score'].replace('8,9', '8.9')

# %%
df['score']=df['score'].replace('9,.0', '9.0')

# %%
df['score']=df['score'].replace('8..8', '8.8')

# %%
df['score']=df['score'].replace('8:8', '8.8')

# %%
df['score']=df['score'].replace('++8.7', '8.7')

# %%
df['score']=df['score'].replace('8.7.', '8.7')

# %%
df['score']=df['score'].replace('8,7e-0', '8.7')

# %%
df['score']=df['score'].replace('8,6', '8.6')

# %%
df['score']=df['score'].replace('8,9f', '8.9')

# %%
df['income']=df['income'].replace('$ 408,035,783', '$ 408035783')

# %%
df['country']=df['country'].replace('USA', 'United States')

# %%
df['country']=df['country'].replace('US', 'United States')

# %%
df['release_year']=df['release_year'].replace('09 21 1972', '1972-09-21')

# %%
df['score']=df['score'].replace('9.', '9.0')

# %%
df['release_year']=df['release_year'].replace('23rd December of 1966', '1966-12-23')

# %%
df[df['release_year']=='The 6th of marzo, year 1951']
# Out:
#    original_title                 release_year             genre duration  \
# 70   Sunset Blvd.  The 6th of marzo, year 1951  Drama, Film-Noir      110
#
#           country content_rating      director    income    votes score
# 70  United States            NaN  Billy Wilder  $ 299645  195.789   8.0

# %%
df['release_year']=df['release_year'].replace('The 6th of marzo, year 1951', '1950/08/10')

# %%
#### Another method that can be used to replace values
df[df['release_year']=='1984-02-34']
# Out:
#    original_title release_year         genre duration        country  \
# 83       Scarface   1984-02-34  Crime, Drama      170  United States
#
#    content_rating        director      income    votes score
# 83              R  Brian De Palma  $ 66023585  721.343   7.8

# %%
df.loc[83,'release_year'] = '1984-02-09'

# %%
df[df['release_year']=='1976-13-24']
# Out:
#    original_title release_year         genre duration        country  \
# 84    Taxi Driver   1976-13-24  Crime, Drama      114  United States
#
#    content_rating         director      income    votes score
# 84              R  Martin Scorsese  $ 28441292  703.264   7.7

# %%
df.loc[84,'release_year'] = '1976-02-08'

# %%
df.loc[2,'release_year'] = '2008-07-23'

# %%
df[df['release_year']=='22 Feb 04']
# Out:
#                                   original_title release_year  \
# 5  The Lord of the Rings: The Return of the King    22 Feb 04
#
#                       genre duration      country content_rating  \
# 5  Action, Adventure, Drama      201  New Zealand          PG-13
#
#         director        income      votes score
# 5  Peter Jackson  $ 1142271098  1.604.280  08.9

# %%
df.loc[5,'release_year'] = '2003-12-19'

# %%
df[df['release_year']=='10-29-99']
# Out:
#   original_title release_year  genre duration country content_rating  \
# 9     Fight Club     10-29-99  Drama      Inf      UK              R
#
#         director       income      votes score
# 9  David Fincher  $ 101218804  1.807.440   8.8

# %%
df.loc[9,'release_year'] = '1999-10-29'

# %%
df.loc[12,'release_year'] = '1966-12-23'

# %%
df[df['release_year']=='01/16-03']
# Out:
#                            original_title release_year   genre  duration  \
# 15  The Lord of the Rings: The Two Towers     01/16-03  Action       179
#
#        country content_rating       director     income    votes  score
# 15  New Zeland          PG-13  Peter Jackson  951227416  1449778    8.7

# %%
df.loc[15,'release_year'] = '2003-01-03'

# %%
df[df['release_year']=='21-11-46']
# Out:
#    original_title release_year  genre  duration        country content_rating  \
# 45     Casablanca     21-11-46  Drama       102  United States             PG
#
#           director   income   votes  score
# 45  Michael Curtiz  4374761  509953    8.3

# %%
df.loc[45,'release_year'] = '1943-01-23'

# %%
df[df['release_year']=='18/11/1976']
# Out:
#                      original_title release_year  genre  duration  \
# 18  One Flew Over the Cuckoo's Nest   18/11/1976  Drama         0
#
#           country content_rating      director     income   votes  score
# 18  United States              R  Milos Forman  108997629  891071    8.7

# %%
df.loc[18,'release_year'] = '1976-11-18'

# %% [markdown]
# ### Convert String to Date

# %%
df['release_year']=pd.to_datetime(df['release_year'],format="%Y/%m/%d")

# %% [markdown]
# ### Splitting Columns

# %%
df['genre'] = df['genre'].str.split(',', expand = True)[0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   original_title  100 non-null    object
#  1   release_year    100 non-null    object
#  2   genre           100 non-null    object
#  3   duration        99 non-null     object
#  4   country         100 non-null    object
#  5   content_rating  77 non-null     object
#  6   director        100 non-null    object
#  7   income          100 non-null    object
#  8   votes           100 non-null    object
#  9   score           100 non-null    object
# dtypes: object(10)
# memory usage: 12.7+ KB

# %% [markdown]
# ### Converting Strings To Numbers

# %%
df = df.assign(income = pd.to_numeric(df['income'].str.replace('[^0-9.]', '', regex=True)))

# %%
df['votes'] = df['votes'].str.replace('.', '',regex=True).astype(int)

# %%
df['score'] = df['score'].astype('float')

# %%
pd.set_option('display.max_rows', 10)

# %%
df['duration']=df['duration'].replace(['Nan',' ','Inf','Not Applicable','-'],0)

# %%
df['duration']=df['duration'].replace('178c', 178)

# %%
df['duration']=df['duration'].fillna(0)

# %%
df['duration'] = df['duration'].astype('int')

# %%
df.head()
# Out:
#              original_title release_year   genre  duration        country  \
# 0  The Shawshank Redemption   1995-02-10   Drama       142  United States
# 1             The Godfather   1972-09-21   Crime       175  United States
# 2           The Dark Knight   2008-07-23  Action       152  United States
# 3    The Godfather: Part II   1975-09-25   Crime       220  United States
# 4              Pulp Fiction   1994-10-28   Crime         0  United States
#
#   content_rating              director      income    votes  score
# 0              R        Frank Darabont    28815245  2278845    9.3
# 1              R  Francis Ford Coppola   246120974  1572674    9.2
# 2          PG-13     Christopher Nolan  1005455211  2241615    9.0
# 3              R  Francis Ford Coppola   408035783  1098714    9.0
# 4              R     Quentin Tarantino   222831817  1780147    8.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   original_title  100 non-null    object
#  1   release_year    100 non-null    datetime64[ns]
#  2   genre           100 non-null    object
#  3   duration        100 non-null    int32
#  4   country         100 non-null    object
#  5   content_rating  77 non-null     object
#  6   director        100 non-null    object
#  7   income          100 non-null    int64
#  8   votes           100 non-null    int32
#  9   score           100 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int32(2), int64(1), object(5)
# memory usage: 11.9+ KB

# %%
df
# Out:
#                   original_title release_year      genre  duration  \
# 0       The Shawshank Redemption   1995-02-10      Drama       142
# 1                  The Godfather   1972-09-21      Crime       175
# 2                The Dark Knight   2008-07-23     Action       152
# 3         The Godfather: Part II   1975-09-25      Crime       220
# 4                   Pulp Fiction   1994-10-28      Crime         0
# ..                           ...          ...        ...       ...
# 96                     The Sting   1974-03-21     Comedy       129
# 97                      Das Boot   1982-03-18  Adventure       149
# 98   Per qualche dollaro in piÃ¹   1965-12-20    Western       132
# 99       Jodaeiye Nader az Simin   2011-10-21      Drama       123
# 100          Singin' in the Rain   1953-02-05     Comedy       103
#
#            country content_rating              director      income    votes  \
# 0    United States              R        Frank Darabont    28815245  2278845
# ...
